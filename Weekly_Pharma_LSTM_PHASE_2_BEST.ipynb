# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15,8]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Thesis datasets/Weekly_Pharmaceutical_sales.csv')
df.head()
# Out:
#        datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0   1/5/2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  1/12/2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2  1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3  1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4   2/2/2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df.tail()
# Out:
#           datum  M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# 297   9/15/2019  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 298   9/22/2019  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 299   9/29/2019  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 300   10/6/2019  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 301  10/13/2019   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00

# %%
df.shape
# Out:
# (302, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   datum   302 non-null    object
#  1   M01AB   302 non-null    float64
#  2   M01AE   302 non-null    float64
#  3   N02BA   302 non-null    float64
#  4   N02BE   302 non-null    float64
#  5   N05B    302 non-null    float64
#  6   N05C    302 non-null    float64
#  7   R03     302 non-null    float64
#  8   R06     302 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 21.4+ KB

# %%
time = pd.date_range(start='1/5/2014',periods=302,freq='W')
df['time_stamp'] = pd.DataFrame(time)
df.drop('datum',axis=1,inplace=True)
df = df.set_index('time_stamp')

# %%
df.head()
# Out:
#             M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# time_stamp
# 2014-01-05  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 2014-01-12  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2014-01-19  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 2014-01-26  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 2014-02-02  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df.tail()
# Out:
#             M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# time_stamp
# 2019-09-15  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 2019-09-22  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 2019-09-29  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 2019-10-06  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 2019-10-13   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00

# %%
df = df[['N02BE']]
df
# Out:
#               N02BE
# time_stamp
# 2014-01-05  185.950
# 2014-01-12  190.700
# 2014-01-19  218.400
# 2014-01-26  179.600
# 2014-02-02  159.880
# ...             ...
# 2019-09-15  178.375
# 2019-09-22  248.250
# 2019-09-29  336.700
# 2019-10-06  249.450
# 2019-10-13   95.100
#
# [302 rows x 1 columns]

# %%
plt.plot(df)
plt.title('Weekly Pharmaceutical Sales',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
from sklearn.preprocessing import MinMaxScaler
#create numpy.ndarray 
df['N02BE'] = df['N02BE'].astype(np.float32)
df_arr = df.values
df_arr = np.reshape(df_arr, (-1, 1)) #LTSM requires more input features compared to RNN or DNN
scaler = MinMaxScaler(feature_range=(0, 1))#LTSM is senstive to the scale of features
df_arr = scaler.fit_transform(df_arr)

# %%
#Split data set into testing dataset and train dataset
train_size = 267
train, test = df_arr[0:train_size,:], df_arr[train_size:len(df_arr),:]
# setup look_back window 
look_back = 5
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (262, 1, 5)
# (1, 262)
# (30, 1, 5)
# (1, 30)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 133 kB 9.3 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,Dropout,Bidirectional,BatchNormalization,LeakyReLU
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(LSTM(hp.Int('first_lstm_layer',min_value=16,max_value=256,step=16), activation="relu",return_sequences=True, input_shape=(1,look_back),recurrent_dropout = hp.Choice("first_recurrent_dropout",[0.2,0.4,0.6],default=0.4)))
    model.add(LSTM(hp.Int('final_lstm_layer',min_value=16,max_value=256,step=16),activation="relu",recurrent_dropout = hp.Choice("last_recurrent_dropout",[0.2,0.4,0.6],default=0.4) ))
    model.add(Dense(hp.Int('dense_layer_1',min_value=16,max_value=256,step=16),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate_1',min_value=0,max_value=0.5,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-4, max_value=1e-1, sampling="log")),
        loss='mape',
        metrics=['mape'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mape',
    max_trials=20,
    executions_per_trial=2,
    directory='project',
    project_name='pharma Sales_4')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# first_lstm_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 16, 'sampling': None}
# first_recurrent_dropout (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# final_lstm_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 16, 'sampling': None}
# last_recurrent_dropout (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 16, 'sampling': None}
# Dropout_rate_1 (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=200,
             batch_size=30,
             validation_data=(testX, testY))
# Out:
# Trial 20 Complete [00h 00m 47s]
# val_mape: 21.361492156982422
#
# Best val_mape So Far: 18.594181060791016
# Total elapsed time: 00h 22m 28s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/pharma Sales_4
# Showing 10 best trials
# Objective(name='val_mape', direction='min')
# Trial summary
# Hyperparameters:
# first_lstm_layer: 32
# first_recurrent_dropout: 0.4
# final_lstm_layer: 80
# last_recurrent_dropout: 0.4
# dense_layer_1: 240
# Dropout_rate_1: 0.2
# learning_rate: 0.00016836000714040867
# Score: 18.594181060791016
# Trial summary
# Hyperparameters:
# first_lstm_layer: 16
# first_recurrent_dropout: 0.2
# final_lstm_layer: 224
# last_recurrent_dropout: 0.6
# dense_layer_1: 80
# Dropout_rate_1: 0.0
# learning_rate: 0.00017541406166518252
# Score: 20.200878143310547
# Trial summary
# Hyperparameters:
# first_lstm_layer: 224
# first_recurrent_dropout: 0.4
# final_lstm_layer: 16
# last_recurrent_dropout: 0.4
# dense_layer_1: 64
# Dropout_rate_1: 0.5
# learning_rate: 0.0003472032849266493
# Score: 20.823944091796875
# Trial summary
# Hyperparameters:
# first_lstm_layer: 96
# first_recurrent_dropout: 0.2
# final_lstm_layer: 80
# last_recurrent_dropout: 0.6
# dense_layer_1: 96
# Dropout_rate_1: 0.5
# learning_rate: 0.004561701435464844
# Score: 20.925705909729004
# Trial summary
# Hyperparameters:
# first_lstm_layer: 160
# first_recurrent_dropout: 0.4
# final_lstm_layer: 80
# last_recurrent_dropout: 0.6
# dense_layer_1: 64
# Dropout_rate_1: 0.5
# learning_rate: 0.04024407148788527
# Score: 21.112905502319336
# Trial summary
# Hyperparameters:
# first_lstm_layer: 256
# first_recurrent_dropout: 0.4
# final_lstm_layer: 224
# last_recurrent_dropout: 0.4
# dense_layer_1: 80
# Dropout_rate_1: 0.4
# learning_rate: 0.0005356799746182838
# Score: 21.151822090148926
# Trial summary
# Hyperparameters:
# first_lstm_layer: 192
# first_recurrent_dropout: 0.2
# final_lstm_layer: 32
# last_recurrent_dropout: 0.2
# dense_layer_1: 96
# Dropout_rate_1: 0.1
# learning_rate: 0.049933530062390506
# Score: 21.159128189086914
# Trial summary
# Hyperparameters:
# first_lstm_layer: 144
# first_recurrent_dropout: 0.6
# final_lstm_layer: 208
# last_recurrent_dropout: 0.4
# dense_layer_1: 96
# Dropout_rate_1: 0.2
# learning_rate: 0.0018610025266868012
# Score: 21.270270347595215
# Trial summary
# Hyperparameters:
# first_lstm_layer: 144
# first_recurrent_dropout: 0.6
# final_lstm_layer: 112
# last_recurrent_dropout: 0.2
# dense_layer_1: 96
# Dropout_rate_1: 0.0
# learning_rate: 0.00011455292256091957
# Score: 21.299689292907715
# Trial summary
# Hyperparameters:
# first_lstm_layer: 64
# first_recurrent_dropout: 0.2
# final_lstm_layer: 96
# last_recurrent_dropout: 0.6
# dense_layer_1: 48
# Dropout_rate_1: 0.30000000000000004
# learning_rate: 0.03378021766664862
# Score: 21.361492156982422

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(None, 6))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 32)             4992
#
#  lstm_1 (LSTM)               (None, 80)                36160
#
#  dense (Dense)               (None, 240)               19440
#
#  dropout (Dropout)           (None, 240)               0
#
#  dense_1 (Dense)             (None, 1)                 241
#
# =================================================================
# Total params: 60,833
# Trainable params: 60,833
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
from tensorflow.keras import optimizers

# %%
model = Sequential()
model.add(LSTM(32,activation='relu',input_shape=(1,look_back),return_sequences=True, recurrent_dropout = 0.1))
model.add(LSTM(80,activation='relu', recurrent_dropout = 0.1))
model.add(Dense(16,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate=0.00016836000714040867)
model.compile(optimizer = ad, loss = 'mae', metrics = ['mae'])
model_history=model.fit(trainX, trainY,validation_data=(testX, testY), batch_size = 30, epochs = 200)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 31s 75ms/step - loss: 0.2751 - mae: 0.2751 - val_loss: 0.1497 - val_mae: 0.1497
# Epoch 2/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2672 - mae: 0.2672 - val_loss: 0.1419 - val_mae: 0.1419
# Epoch 3/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2584 - mae: 0.2584 - val_loss: 0.1340 - val_mae: 0.1340
# Epoch 4/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2494 - mae: 0.2494 - val_loss: 0.1260 - val_mae: 0.1260
# Epoch 5/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2407 - mae: 0.2407 - val_loss: 0.1177 - val_mae: 0.1177
# Epoch 6/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2307 - mae: 0.2307 - val_loss: 0.1091 - val_mae: 0.1091
# Epoch 7/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2222 - mae: 0.2222 - val_loss: 0.1002 - val_mae: 0.1002
# Epoch 8/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2119 - mae: 0.2119 - val_loss: 0.0922 - val_mae: 0.0922
# Epoch 9/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2028 - mae: 0.2028 - val_loss: 0.0854 - val_mae: 0.0854
# Epoch 10/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1941 - mae: 0.1941 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 11/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1859 - mae: 0.1859 - val_loss: 0.0775 - val_mae: 0.0775
# Epoch 12/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1749 - mae: 0.1749 - val_loss: 0.0745 - val_mae: 0.0745
# Epoch 13/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1646 - mae: 0.1646 - val_loss: 0.0721 - val_mae: 0.0721
# Epoch 14/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1589 - mae: 0.1589 - val_loss: 0.0709 - val_mae: 0.0709
# Epoch 15/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1523 - mae: 0.1523 - val_loss: 0.0716 - val_mae: 0.0716
# Epoch 16/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1447 - mae: 0.1447 - val_loss: 0.0753 - val_mae: 0.0753
# Epoch 17/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1395 - mae: 0.1395 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 18/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1362 - mae: 0.1362 - val_loss: 0.0862 - val_mae: 0.0862
# Epoch 19/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1316 - mae: 0.1316 - val_loss: 0.0909 - val_mae: 0.0909
# Epoch 20/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1268 - mae: 0.1268 - val_loss: 0.0953 - val_mae: 0.0953
# Epoch 21/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1238 - mae: 0.1238 - val_loss: 0.1003 - val_mae: 0.1003
# Epoch 22/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1211 - mae: 0.1211 - val_loss: 0.1048 - val_mae: 0.1048
# Epoch 23/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1191 - mae: 0.1191 - val_loss: 0.1079 - val_mae: 0.1079
# Epoch 24/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1198 - mae: 0.1198 - val_loss: 0.1107 - val_mae: 0.1107
# Epoch 25/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1111 - mae: 0.1111 - val_loss: 0.1121 - val_mae: 0.1121
# Epoch 26/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1135 - mae: 0.1135 - val_loss: 0.1132 - val_mae: 0.1132
# Epoch 27/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1174 - mae: 0.1174 - val_loss: 0.1126 - val_mae: 0.1126
# Epoch 28/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1154 - mae: 0.1154 - val_loss: 0.1125 - val_mae: 0.1125
# Epoch 29/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1116 - mae: 0.1116 - val_loss: 0.1114 - val_mae: 0.1114
# Epoch 30/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1211 - mae: 0.1211 - val_loss: 0.1100 - val_mae: 0.1100
# Epoch 31/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1145 - mae: 0.1145 - val_loss: 0.1067 - val_mae: 0.1067
# Epoch 32/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1126 - mae: 0.1126 - val_loss: 0.1046 - val_mae: 0.1046
# Epoch 33/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1042 - mae: 0.1042 - val_loss: 0.1039 - val_mae: 0.1039
# Epoch 34/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1079 - mae: 0.1079 - val_loss: 0.1043 - val_mae: 0.1043
# Epoch 35/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1082 - mae: 0.1082 - val_loss: 0.1046 - val_mae: 0.1046
# Epoch 36/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1100 - mae: 0.1100 - val_loss: 0.1029 - val_mae: 0.1029
# Epoch 37/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1032 - mae: 0.1032 - val_loss: 0.0992 - val_mae: 0.0992
# Epoch 38/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1049 - mae: 0.1049 - val_loss: 0.0964 - val_mae: 0.0964
# Epoch 39/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1001 - mae: 0.1001 - val_loss: 0.0962 - val_mae: 0.0962
# Epoch 40/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1043 - mae: 0.1043 - val_loss: 0.0952 - val_mae: 0.0952
# Epoch 41/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1013 - mae: 0.1013 - val_loss: 0.0946 - val_mae: 0.0946
# Epoch 42/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0991 - mae: 0.0991 - val_loss: 0.0920 - val_mae: 0.0920
# Epoch 43/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0950 - mae: 0.0950 - val_loss: 0.0901 - val_mae: 0.0901
# Epoch 44/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0984 - mae: 0.0984 - val_loss: 0.0890 - val_mae: 0.0890
# Epoch 45/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0945 - mae: 0.0945 - val_loss: 0.0892 - val_mae: 0.0892
# Epoch 46/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0924 - mae: 0.0924 - val_loss: 0.0861 - val_mae: 0.0861
# Epoch 47/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1022 - mae: 0.1022 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 48/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0910 - mae: 0.0910 - val_loss: 0.0826 - val_mae: 0.0826
# Epoch 49/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0898 - mae: 0.0898 - val_loss: 0.0814 - val_mae: 0.0814
# Epoch 50/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0908 - mae: 0.0908 - val_loss: 0.0808 - val_mae: 0.0808
# Epoch 51/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0886 - mae: 0.0886 - val_loss: 0.0787 - val_mae: 0.0787
# Epoch 52/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0873 - mae: 0.0873 - val_loss: 0.0775 - val_mae: 0.0775
# Epoch 53/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0901 - mae: 0.0901 - val_loss: 0.0766 - val_mae: 0.0766
# Epoch 54/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0870 - mae: 0.0870 - val_loss: 0.0738 - val_mae: 0.0738
# Epoch 55/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0887 - mae: 0.0887 - val_loss: 0.0742 - val_mae: 0.0742
# Epoch 56/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0879 - mae: 0.0879 - val_loss: 0.0736 - val_mae: 0.0736
# Epoch 57/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0844 - mae: 0.0844 - val_loss: 0.0750 - val_mae: 0.0750
# Epoch 58/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0852 - mae: 0.0852 - val_loss: 0.0745 - val_mae: 0.0745
# Epoch 59/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0877 - mae: 0.0877 - val_loss: 0.0712 - val_mae: 0.0712
# Epoch 60/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0872 - mae: 0.0872 - val_loss: 0.0718 - val_mae: 0.0718
# Epoch 61/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0853 - mae: 0.0853 - val_loss: 0.0714 - val_mae: 0.0714
# Epoch 62/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0901 - mae: 0.0901 - val_loss: 0.0714 - val_mae: 0.0714
# Epoch 63/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.0714 - val_mae: 0.0714
# Epoch 64/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0831 - mae: 0.0831 - val_loss: 0.0715 - val_mae: 0.0715
# Epoch 65/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0844 - mae: 0.0844 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 66/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0865 - mae: 0.0865 - val_loss: 0.0707 - val_mae: 0.0707
# Epoch 67/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0832 - mae: 0.0832 - val_loss: 0.0719 - val_mae: 0.0719
# Epoch 68/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0829 - mae: 0.0829 - val_loss: 0.0719 - val_mae: 0.0719
# Epoch 69/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0812 - mae: 0.0812 - val_loss: 0.0704 - val_mae: 0.0704
# Epoch 70/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0852 - mae: 0.0852 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 71/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0809 - mae: 0.0809 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 72/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0809 - mae: 0.0809 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 73/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0884 - mae: 0.0884 - val_loss: 0.0682 - val_mae: 0.0682
# Epoch 74/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0789 - mae: 0.0789 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 75/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0790 - mae: 0.0790 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 76/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0806 - mae: 0.0806 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 77/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0827 - mae: 0.0827 - val_loss: 0.0695 - val_mae: 0.0695
# Epoch 78/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0773 - mae: 0.0773 - val_loss: 0.0698 - val_mae: 0.0698
# Epoch 79/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 80/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 81/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.0681 - val_mae: 0.0681
# Epoch 82/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.0684 - val_mae: 0.0684
# Epoch 83/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0831 - mae: 0.0831 - val_loss: 0.0691 - val_mae: 0.0691
# Epoch 84/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0827 - mae: 0.0827 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 85/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0824 - mae: 0.0824 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 86/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0798 - mae: 0.0798 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 87/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0785 - mae: 0.0785 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 88/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0829 - mae: 0.0829 - val_loss: 0.0681 - val_mae: 0.0681
# Epoch 89/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0837 - mae: 0.0837 - val_loss: 0.0688 - val_mae: 0.0688
# Epoch 90/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0799 - mae: 0.0799 - val_loss: 0.0688 - val_mae: 0.0688
# Epoch 91/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0774 - mae: 0.0774 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 92/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 93/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0835 - mae: 0.0835 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 94/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0805 - mae: 0.0805 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 95/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0790 - mae: 0.0790 - val_loss: 0.0679 - val_mae: 0.0679
# Epoch 96/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0825 - mae: 0.0825 - val_loss: 0.0677 - val_mae: 0.0677
# Epoch 97/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0773 - mae: 0.0773 - val_loss: 0.0682 - val_mae: 0.0682
# Epoch 98/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0834 - mae: 0.0834 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 99/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0780 - mae: 0.0780 - val_loss: 0.0680 - val_mae: 0.0680
# Epoch 100/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0800 - mae: 0.0800 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 101/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0739 - mae: 0.0739 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 102/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 103/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0783 - mae: 0.0783 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 104/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0799 - mae: 0.0799 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 105/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0804 - mae: 0.0804 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 106/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0787 - mae: 0.0787 - val_loss: 0.0680 - val_mae: 0.0680
# Epoch 107/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0787 - mae: 0.0787 - val_loss: 0.0680 - val_mae: 0.0680
# Epoch 108/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0669 - val_mae: 0.0669
# Epoch 109/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0822 - mae: 0.0822 - val_loss: 0.0668 - val_mae: 0.0668
# Epoch 110/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0771 - mae: 0.0771 - val_loss: 0.0682 - val_mae: 0.0682
# Epoch 111/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0770 - mae: 0.0770 - val_loss: 0.0677 - val_mae: 0.0677
# Epoch 112/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0809 - mae: 0.0809 - val_loss: 0.0707 - val_mae: 0.0707
# Epoch 113/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0766 - mae: 0.0766 - val_loss: 0.0722 - val_mae: 0.0722
# Epoch 114/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0805 - mae: 0.0805 - val_loss: 0.0707 - val_mae: 0.0707
# Epoch 115/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.0687 - val_mae: 0.0687
# Epoch 116/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0792 - mae: 0.0792 - val_loss: 0.0681 - val_mae: 0.0681
# Epoch 117/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0769 - mae: 0.0769 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 118/200
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0783 - mae: 0.0783 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 119/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0782 - mae: 0.0782 - val_loss: 0.0688 - val_mae: 0.0688
# Epoch 120/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0751 - mae: 0.0751 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 121/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0770 - mae: 0.0770 - val_loss: 0.0677 - val_mae: 0.0677
# Epoch 122/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0680 - val_mae: 0.0680
# Epoch 123/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0816 - mae: 0.0816 - val_loss: 0.0682 - val_mae: 0.0682
# Epoch 124/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0786 - mae: 0.0786 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 125/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0771 - mae: 0.0771 - val_loss: 0.0681 - val_mae: 0.0681
# Epoch 126/200
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0794 - mae: 0.0794 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 127/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0750 - mae: 0.0750 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 128/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 129/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0806 - mae: 0.0806 - val_loss: 0.0679 - val_mae: 0.0679
# Epoch 130/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0792 - mae: 0.0792 - val_loss: 0.0676 - val_mae: 0.0676
# Epoch 131/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0820 - mae: 0.0820 - val_loss: 0.0674 - val_mae: 0.0674
# Epoch 132/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0763 - mae: 0.0763 - val_loss: 0.0681 - val_mae: 0.0681
# Epoch 133/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0684 - val_mae: 0.0684
# Epoch 134/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0779 - mae: 0.0779 - val_loss: 0.0689 - val_mae: 0.0689
# Epoch 135/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0798 - mae: 0.0798 - val_loss: 0.0684 - val_mae: 0.0684
# Epoch 136/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0794 - mae: 0.0794 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 137/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0770 - mae: 0.0770 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 138/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0810 - mae: 0.0810 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 139/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0774 - mae: 0.0774 - val_loss: 0.0678 - val_mae: 0.0678
# Epoch 140/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0780 - mae: 0.0780 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 141/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0782 - mae: 0.0782 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 142/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0751 - mae: 0.0751 - val_loss: 0.0717 - val_mae: 0.0717
# Epoch 143/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0777 - mae: 0.0777 - val_loss: 0.0695 - val_mae: 0.0695
# Epoch 144/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0773 - mae: 0.0773 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 145/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0825 - mae: 0.0825 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 146/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0771 - mae: 0.0771 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 147/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0751 - mae: 0.0751 - val_loss: 0.0697 - val_mae: 0.0697
# Epoch 148/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0737 - mae: 0.0737 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 149/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0679 - val_mae: 0.0679
# Epoch 150/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.0683 - val_mae: 0.0683
# Epoch 151/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0769 - mae: 0.0769 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 152/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0748 - mae: 0.0748 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 153/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0744 - mae: 0.0744 - val_loss: 0.0695 - val_mae: 0.0695
# Epoch 154/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0795 - mae: 0.0795 - val_loss: 0.0708 - val_mae: 0.0708
# Epoch 155/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0713 - val_mae: 0.0713
# Epoch 156/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0775 - mae: 0.0775 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 157/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0805 - mae: 0.0805 - val_loss: 0.0686 - val_mae: 0.0686
# Epoch 158/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0766 - mae: 0.0766 - val_loss: 0.0684 - val_mae: 0.0684
# Epoch 159/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 160/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0791 - mae: 0.0791 - val_loss: 0.0710 - val_mae: 0.0710
# Epoch 161/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0708 - val_mae: 0.0708
# Epoch 162/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0800 - mae: 0.0800 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 163/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0761 - mae: 0.0761 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 164/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 165/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 166/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0790 - mae: 0.0790 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 167/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0729 - mae: 0.0729 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 168/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0784 - mae: 0.0784 - val_loss: 0.0688 - val_mae: 0.0688
# Epoch 169/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.0685 - val_mae: 0.0685
# Epoch 170/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 171/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 172/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 173/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0753 - mae: 0.0753 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 174/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0712 - val_mae: 0.0712
# Epoch 175/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0769 - mae: 0.0769 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 176/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0719 - mae: 0.0719 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 177/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0746 - mae: 0.0746 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 178/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0778 - mae: 0.0778 - val_loss: 0.0709 - val_mae: 0.0709
# Epoch 179/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0772 - mae: 0.0772 - val_loss: 0.0696 - val_mae: 0.0696
# Epoch 180/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0714 - mae: 0.0714 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 181/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0775 - mae: 0.0775 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 182/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0709 - val_mae: 0.0709
# Epoch 183/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0768 - mae: 0.0768 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 184/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0798 - mae: 0.0798 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 185/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0770 - mae: 0.0770 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 186/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0690 - val_mae: 0.0690
# Epoch 187/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 188/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0772 - mae: 0.0772 - val_loss: 0.0693 - val_mae: 0.0693
# Epoch 189/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0761 - mae: 0.0761 - val_loss: 0.0699 - val_mae: 0.0699
# Epoch 190/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0750 - mae: 0.0750 - val_loss: 0.0706 - val_mae: 0.0706
# Epoch 191/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0754 - mae: 0.0754 - val_loss: 0.0705 - val_mae: 0.0705
# Epoch 192/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0792 - mae: 0.0792 - val_loss: 0.0694 - val_mae: 0.0694
# Epoch 193/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0705 - mae: 0.0705 - val_loss: 0.0702 - val_mae: 0.0702
# Epoch 194/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0747 - mae: 0.0747 - val_loss: 0.0707 - val_mae: 0.0707
# Epoch 195/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0738 - mae: 0.0738 - val_loss: 0.0701 - val_mae: 0.0701
# Epoch 196/200
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0771 - mae: 0.0771 - val_loss: 0.0709 - val_mae: 0.0709
# Epoch 197/200
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0728 - mae: 0.0728 - val_loss: 0.0703 - val_mae: 0.0703
# Epoch 198/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0773 - mae: 0.0773 - val_loss: 0.0697 - val_mae: 0.0697
# Epoch 199/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0787 - mae: 0.0787 - val_loss: 0.0692 - val_mae: 0.0692
# Epoch 200/200
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0692 - val_mae: 0.0692

# %%
def model_loss(history):
    plt.figure(figsize=(15,8))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

# invert predictions
train_predict = scaler.inverse_transform(train_predict)
trainY = scaler.inverse_transform([trainY])
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform([testY])
print("Train MAE:",mae(trainY.reshape(-1,),train_predict.reshape(-1,)))
print("Test MAE:",mae(testY.reshape(-1,),test_predict.reshape(-1,)))
model_loss(model_history)
# Out:
# Train MAE: 31.377881665504056
# Test MAE: 31.894752906855768

# %%
def prediction_plot(testY, test_predict,look_back):
    len_prediction=[x for x in range(262,292)]
    plt.plot(trainY.reshape(-1,))
    plt.plot(len_prediction, testY.reshape(-1,), marker='.', label='actual')
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
import seaborn as sns

# %%
test_predict = model.predict(testX)
test_predict = scaler.inverse_transform(test_predict)
prediction_plot(testY, test_predict,look_back)
