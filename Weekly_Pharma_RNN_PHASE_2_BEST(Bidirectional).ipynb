# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15,8]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Thesis datasets/Weekly_Pharmaceutical_sales.csv')
df.head()
# Out:
#        datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0   1/5/2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  1/12/2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2  1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3  1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4   2/2/2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df.tail()
# Out:
#           datum  M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# 297   9/15/2019  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 298   9/22/2019  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 299   9/29/2019  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 300   10/6/2019  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 301  10/13/2019   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00

# %%
df.shape
# Out:
# (302, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   datum   302 non-null    object
#  1   M01AB   302 non-null    float64
#  2   M01AE   302 non-null    float64
#  3   N02BA   302 non-null    float64
#  4   N02BE   302 non-null    float64
#  5   N05B    302 non-null    float64
#  6   N05C    302 non-null    float64
#  7   R03     302 non-null    float64
#  8   R06     302 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 21.4+ KB

# %%
time = pd.date_range(start='1/5/2014',periods=302,freq='W')
df['time_stamp'] = pd.DataFrame(time)
df.drop('datum',axis=1,inplace=True)
df = df.set_index('time_stamp')

# %%
df.head()
# Out:
#             M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# time_stamp
# 2014-01-05  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 2014-01-12  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2014-01-19  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 2014-01-26  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 2014-02-02  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df.tail()
# Out:
#             M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# time_stamp
# 2019-09-15  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 2019-09-22  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 2019-09-29  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 2019-10-06  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 2019-10-13   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00

# %%
df = df[['N02BE']]
df
# Out:
#               N02BE
# time_stamp
# 2014-01-05  185.950
# 2014-01-12  190.700
# 2014-01-19  218.400
# 2014-01-26  179.600
# 2014-02-02  159.880
# ...             ...
# 2019-09-15  178.375
# 2019-09-22  248.250
# 2019-09-29  336.700
# 2019-10-06  249.450
# 2019-10-13   95.100
#
# [302 rows x 1 columns]

# %%
plt.plot(df)
plt.title('Weekly Pharmaceutical Sales',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
from sklearn.preprocessing import MinMaxScaler
#create numpy.ndarray 
df['N02BE'] = df['N02BE'].astype(np.float32)
df_arr = df.values
df_arr = np.reshape(df_arr, (-1, 1))
scaler = MinMaxScaler(feature_range=(0.1, 1))
df_arr = scaler.fit_transform(df_arr)

# %%
#Split data set into testing dataset and train dataset
train_size = 270
train, test =df_arr[0:train_size,:], df_arr[train_size:len(df_arr),:]
# setup look_back window 
look_back = 1
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
# reshape input to be [samples, window size, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (269, 1, 1)
# (269,)
# (31, 1, 1)
# (31,)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 133 kB 5.1 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,Dropout,SimpleRNN,Bidirectional,LeakyReLU
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(SimpleRNN(hp.Int('rnn_layer_1',min_value=8,max_value=256,step=8), activation="relu",return_sequences=True, input_shape=(1,look_back),recurrent_dropout = hp.Choice("first_recurrent_dropout",[0.1,0.2,0.3],default=0.2)))
    for i in range(hp.Int('n_layers', 1, 10)):
        model.add(SimpleRNN(hp.Int(f'rnn_{i}_units',min_value=8,max_value=256,step=8),activation="relu", return_sequences=True,recurrent_dropout = hp.Choice(f"recurrent_dropout_{i}",[0.1,0.2,0.3],default=0.3)))
    model.add(SimpleRNN(hp.Int('final_rnn_layer',min_value=8,max_value=256,step=8),activation="relu",recurrent_dropout = hp.Choice("last_recurrent_dropout",[0.1,0.2,0.3],default=0.2) ))
    model.add(Dense(hp.Int('dense_layer_1',min_value=8,max_value=256,step=8),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.3,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-4, max_value=1e-1, sampling="log")),
        loss='mae',
        metrics=['mae'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mae',
    max_trials=20,
    executions_per_trial=1,
    directory='project',
    project_name='pharma Sales_4')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 10
# rnn_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# first_recurrent_dropout (Choice)
# {'default': 0.2, 'conditions': [], 'values': [0.1, 0.2, 0.3], 'ordered': True}
# n_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 10, 'step': 1, 'sampling': None}
# rnn_0_units (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# recurrent_dropout_0 (Choice)
# {'default': 0.3, 'conditions': [], 'values': [0.1, 0.2, 0.3], 'ordered': True}
# final_rnn_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# last_recurrent_dropout (Choice)
# {'default': 0.2, 'conditions': [], 'values': [0.1, 0.2, 0.3], 'ordered': True}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# Dropout_rate (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.3, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=200,
             batch_size=30,
             validation_data=(testX, testY))
# Out:
# Trial 20 Complete [00h 00m 46s]
# val_mae: 0.05739332363009453
#
# Best val_mae So Far: 0.05650730058550835
# Total elapsed time: 00h 17m 12s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/pharma Sales_4
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f5949dcc210>
# Trial summary
# Hyperparameters:
# rnn_layer_1: 136
# first_recurrent_dropout: 0.2
# n_layers: 1
# rnn_0_units: 128
# recurrent_dropout_0: 0.2
# final_rnn_layer: 96
# last_recurrent_dropout: 0.2
# dense_layer_1: 120
# Dropout_rate: 0.1
# learning_rate: 0.0012859725366202068
# Score: 0.05650730058550835
# Trial summary
# Hyperparameters:
# rnn_layer_1: 16
# first_recurrent_dropout: 0.2
# n_layers: 5
# rnn_0_units: 112
# recurrent_dropout_0: 0.3
# final_rnn_layer: 232
# last_recurrent_dropout: 0.3
# dense_layer_1: 56
# Dropout_rate: 0.1
# learning_rate: 0.004212815235973015
# rnn_1_units: 104
# recurrent_dropout_1: 0.1
# rnn_2_units: 16
# recurrent_dropout_2: 0.2
# rnn_3_units: 200
# recurrent_dropout_3: 0.1
# rnn_4_units: 232
# recurrent_dropout_4: 0.1
# rnn_5_units: 24
# recurrent_dropout_5: 0.2
# rnn_6_units: 160
# recurrent_dropout_6: 0.2
# rnn_7_units: 144
# recurrent_dropout_7: 0.2
# rnn_8_units: 232
# recurrent_dropout_8: 0.3
# rnn_9_units: 232
# recurrent_dropout_9: 0.3
# Score: 0.05698210373520851
# Trial summary
# Hyperparameters:
# rnn_layer_1: 72
# first_recurrent_dropout: 0.2
# n_layers: 5
# rnn_0_units: 104
# recurrent_dropout_0: 0.2
# final_rnn_layer: 208
# last_recurrent_dropout: 0.1
# dense_layer_1: 200
# Dropout_rate: 0.1
# learning_rate: 0.013103833405625648
# rnn_1_units: 104
# recurrent_dropout_1: 0.3
# rnn_2_units: 216
# recurrent_dropout_2: 0.1
# rnn_3_units: 144
# recurrent_dropout_3: 0.3
# rnn_4_units: 8
# recurrent_dropout_4: 0.3
# Score: 0.05721501260995865
# Trial summary
# Hyperparameters:
# rnn_layer_1: 112
# first_recurrent_dropout: 0.2
# n_layers: 4
# rnn_0_units: 8
# recurrent_dropout_0: 0.3
# final_rnn_layer: 120
# last_recurrent_dropout: 0.1
# dense_layer_1: 104
# Dropout_rate: 0.2
# learning_rate: 0.00423203804983054
# rnn_1_units: 120
# recurrent_dropout_1: 0.1
# rnn_2_units: 88
# recurrent_dropout_2: 0.1
# rnn_3_units: 48
# recurrent_dropout_3: 0.1
# rnn_4_units: 136
# recurrent_dropout_4: 0.3
# rnn_5_units: 192
# recurrent_dropout_5: 0.3
# rnn_6_units: 128
# recurrent_dropout_6: 0.3
# rnn_7_units: 88
# recurrent_dropout_7: 0.3
# rnn_8_units: 232
# recurrent_dropout_8: 0.3
# rnn_9_units: 160
# recurrent_dropout_9: 0.2
# Score: 0.05724233016371727
# Trial summary
# Hyperparameters:
# rnn_layer_1: 16
# first_recurrent_dropout: 0.3
# n_layers: 6
# rnn_0_units: 144
# recurrent_dropout_0: 0.3
# final_rnn_layer: 120
# last_recurrent_dropout: 0.3
# dense_layer_1: 24
# Dropout_rate: 0.1
# learning_rate: 0.006216048325841321
# rnn_1_units: 240
# recurrent_dropout_1: 0.2
# rnn_2_units: 80
# recurrent_dropout_2: 0.1
# rnn_3_units: 56
# recurrent_dropout_3: 0.1
# rnn_4_units: 32
# recurrent_dropout_4: 0.2
# rnn_5_units: 72
# recurrent_dropout_5: 0.3
# rnn_6_units: 128
# recurrent_dropout_6: 0.1
# rnn_7_units: 200
# recurrent_dropout_7: 0.2
# rnn_8_units: 64
# recurrent_dropout_8: 0.3
# rnn_9_units: 80
# recurrent_dropout_9: 0.3
# Score: 0.05728267878293991
# Trial summary
# Hyperparameters:
# rnn_layer_1: 152
# first_recurrent_dropout: 0.2
# n_layers: 3
# rnn_0_units: 48
# recurrent_dropout_0: 0.3
# final_rnn_layer: 240
# last_recurrent_dropout: 0.1
# dense_layer_1: 248
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.012172793543242971
# rnn_1_units: 176
# recurrent_dropout_1: 0.1
# rnn_2_units: 144
# recurrent_dropout_2: 0.3
# rnn_3_units: 192
# recurrent_dropout_3: 0.1
# rnn_4_units: 232
# recurrent_dropout_4: 0.1
# rnn_5_units: 80
# recurrent_dropout_5: 0.3
# rnn_6_units: 216
# recurrent_dropout_6: 0.2
# rnn_7_units: 208
# recurrent_dropout_7: 0.1
# rnn_8_units: 32
# recurrent_dropout_8: 0.3
# rnn_9_units: 24
# recurrent_dropout_9: 0.1
# Score: 0.05739332363009453
# Trial summary
# Hyperparameters:
# rnn_layer_1: 232
# first_recurrent_dropout: 0.2
# n_layers: 4
# rnn_0_units: 80
# recurrent_dropout_0: 0.1
# final_rnn_layer: 248
# last_recurrent_dropout: 0.1
# dense_layer_1: 216
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.002837423739934331
# rnn_1_units: 24
# recurrent_dropout_1: 0.2
# rnn_2_units: 128
# recurrent_dropout_2: 0.1
# rnn_3_units: 48
# recurrent_dropout_3: 0.1
# rnn_4_units: 56
# recurrent_dropout_4: 0.2
# rnn_5_units: 240
# recurrent_dropout_5: 0.3
# rnn_6_units: 168
# recurrent_dropout_6: 0.2
# rnn_7_units: 152
# recurrent_dropout_7: 0.2
# rnn_8_units: 184
# recurrent_dropout_8: 0.3
# rnn_9_units: 80
# recurrent_dropout_9: 0.2
# Score: 0.05762115493416786
# Trial summary
# Hyperparameters:
# rnn_layer_1: 256
# first_recurrent_dropout: 0.2
# n_layers: 2
# rnn_0_units: 128
# recurrent_dropout_0: 0.1
# final_rnn_layer: 56
# last_recurrent_dropout: 0.2
# dense_layer_1: 64
# Dropout_rate: 0.1
# learning_rate: 0.005422922002994078
# rnn_1_units: 8
# recurrent_dropout_1: 0.3
# Score: 0.05808315426111221
# Trial summary
# Hyperparameters:
# rnn_layer_1: 80
# first_recurrent_dropout: 0.1
# n_layers: 2
# rnn_0_units: 16
# recurrent_dropout_0: 0.3
# final_rnn_layer: 184
# last_recurrent_dropout: 0.3
# dense_layer_1: 8
# Dropout_rate: 0.1
# learning_rate: 0.00015221160588282871
# rnn_1_units: 96
# recurrent_dropout_1: 0.2
# rnn_2_units: 248
# recurrent_dropout_2: 0.3
# rnn_3_units: 224
# recurrent_dropout_3: 0.2
# rnn_4_units: 56
# recurrent_dropout_4: 0.2
# rnn_5_units: 128
# recurrent_dropout_5: 0.1
# rnn_6_units: 64
# recurrent_dropout_6: 0.3
# rnn_7_units: 40
# recurrent_dropout_7: 0.1
# rnn_8_units: 208
# recurrent_dropout_8: 0.3
# rnn_9_units: 64
# recurrent_dropout_9: 0.3
# Score: 0.05839492753148079
# Trial summary
# Hyperparameters:
# rnn_layer_1: 32
# first_recurrent_dropout: 0.2
# n_layers: 3
# rnn_0_units: 200
# recurrent_dropout_0: 0.3
# final_rnn_layer: 72
# last_recurrent_dropout: 0.1
# dense_layer_1: 40
# Dropout_rate: 0.2
# learning_rate: 0.0037021134581445704
# rnn_1_units: 24
# recurrent_dropout_1: 0.1
# rnn_2_units: 192
# recurrent_dropout_2: 0.2
# rnn_3_units: 240
# recurrent_dropout_3: 0.1
# rnn_4_units: 120
# recurrent_dropout_4: 0.3
# rnn_5_units: 16
# recurrent_dropout_5: 0.2
# rnn_6_units: 96
# recurrent_dropout_6: 0.2
# rnn_7_units: 184
# recurrent_dropout_7: 0.2
# rnn_8_units: 176
# recurrent_dropout_8: 0.3
# rnn_9_units: 192
# recurrent_dropout_9: 0.1
# Score: 0.0585615411400795

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(None, 1))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 136)            18768
#
#  simple_rnn_1 (SimpleRNN)    (None, 1, 128)            33920
#
#  simple_rnn_2 (SimpleRNN)    (None, 96)                21600
#
#  dense (Dense)               (None, 120)               11640
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# =================================================================
# Total params: 86,049
# Trainable params: 86,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

# %%
model = Sequential()
model.add(Bidirectional(SimpleRNN(136,activation='relu',input_shape=(1,look_back),return_sequences=True)))
model.add(Bidirectional(SimpleRNN(128,activation='relu',return_sequences=True)))
model.add(Bidirectional(SimpleRNN(96,activation='relu')))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate=0.000012859725366202068)
model.compile(optimizer = ad, loss = 'mae', metrics = ['mae'])
model_history=model.fit(trainX, trainY,validation_data=(testX, testY), batch_size = 30, epochs = 100)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 7s 198ms/step - loss: 0.3517 - mae: 0.3517 - val_loss: 0.2432 - val_mae: 0.2432
# Epoch 2/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3414 - mae: 0.3414 - val_loss: 0.2349 - val_mae: 0.2349
# Epoch 3/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3310 - mae: 0.3310 - val_loss: 0.2266 - val_mae: 0.2266
# Epoch 4/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3206 - mae: 0.3206 - val_loss: 0.2184 - val_mae: 0.2184
# Epoch 5/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3104 - mae: 0.3104 - val_loss: 0.2103 - val_mae: 0.2103
# Epoch 6/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3002 - mae: 0.3002 - val_loss: 0.2021 - val_mae: 0.2021
# Epoch 7/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2899 - mae: 0.2899 - val_loss: 0.1938 - val_mae: 0.1938
# Epoch 8/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2793 - mae: 0.2793 - val_loss: 0.1854 - val_mae: 0.1854
# Epoch 9/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2685 - mae: 0.2685 - val_loss: 0.1771 - val_mae: 0.1771
# Epoch 10/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2580 - mae: 0.2580 - val_loss: 0.1689 - val_mae: 0.1689
# Epoch 11/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2476 - mae: 0.2476 - val_loss: 0.1615 - val_mae: 0.1615
# Epoch 12/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2373 - mae: 0.2373 - val_loss: 0.1546 - val_mae: 0.1546
# Epoch 13/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2275 - mae: 0.2275 - val_loss: 0.1475 - val_mae: 0.1475
# Epoch 14/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2175 - mae: 0.2175 - val_loss: 0.1408 - val_mae: 0.1408
# Epoch 15/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2079 - mae: 0.2079 - val_loss: 0.1344 - val_mae: 0.1344
# Epoch 16/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1981 - mae: 0.1981 - val_loss: 0.1279 - val_mae: 0.1279
# Epoch 17/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1884 - mae: 0.1884 - val_loss: 0.1214 - val_mae: 0.1214
# Epoch 18/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1787 - mae: 0.1787 - val_loss: 0.1149 - val_mae: 0.1149
# Epoch 19/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1689 - mae: 0.1689 - val_loss: 0.1084 - val_mae: 0.1084
# Epoch 20/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1594 - mae: 0.1594 - val_loss: 0.1017 - val_mae: 0.1017
# Epoch 21/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1497 - mae: 0.1497 - val_loss: 0.0948 - val_mae: 0.0948
# Epoch 22/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1397 - mae: 0.1397 - val_loss: 0.0881 - val_mae: 0.0881
# Epoch 23/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1302 - mae: 0.1302 - val_loss: 0.0817 - val_mae: 0.0817
# Epoch 24/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1208 - mae: 0.1208 - val_loss: 0.0765 - val_mae: 0.0765
# Epoch 25/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1121 - mae: 0.1121 - val_loss: 0.0716 - val_mae: 0.0716
# Epoch 26/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1037 - mae: 0.1037 - val_loss: 0.0671 - val_mae: 0.0671
# Epoch 27/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0962 - mae: 0.0962 - val_loss: 0.0635 - val_mae: 0.0635
# Epoch 28/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0895 - mae: 0.0895 - val_loss: 0.0609 - val_mae: 0.0609
# Epoch 29/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0839 - mae: 0.0839 - val_loss: 0.0600 - val_mae: 0.0600
# Epoch 30/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0796 - mae: 0.0796 - val_loss: 0.0596 - val_mae: 0.0596
# Epoch 31/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0761 - mae: 0.0761 - val_loss: 0.0598 - val_mae: 0.0598
# Epoch 32/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0732 - mae: 0.0732 - val_loss: 0.0603 - val_mae: 0.0603
# Epoch 33/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0708 - mae: 0.0708 - val_loss: 0.0609 - val_mae: 0.0609
# Epoch 34/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0616 - val_mae: 0.0616
# Epoch 35/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0673 - mae: 0.0673 - val_loss: 0.0622 - val_mae: 0.0622
# Epoch 36/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0665 - mae: 0.0665 - val_loss: 0.0627 - val_mae: 0.0627
# Epoch 37/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0658 - mae: 0.0658 - val_loss: 0.0631 - val_mae: 0.0631
# Epoch 38/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0656 - mae: 0.0656 - val_loss: 0.0634 - val_mae: 0.0634
# Epoch 39/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0654 - mae: 0.0654 - val_loss: 0.0637 - val_mae: 0.0637
# Epoch 40/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0653 - mae: 0.0653 - val_loss: 0.0639 - val_mae: 0.0639
# Epoch 41/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0653 - mae: 0.0653 - val_loss: 0.0641 - val_mae: 0.0641
# Epoch 42/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0653 - mae: 0.0653 - val_loss: 0.0642 - val_mae: 0.0642
# Epoch 43/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0643 - val_mae: 0.0643
# Epoch 44/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0644 - val_mae: 0.0644
# Epoch 45/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0643 - val_mae: 0.0643
# Epoch 46/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0644 - val_mae: 0.0644
# Epoch 47/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 48/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0644 - val_mae: 0.0644
# Epoch 49/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0644 - val_mae: 0.0644
# Epoch 50/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 51/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 52/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 53/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 54/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 55/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0651 - mae: 0.0651 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 56/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 57/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 58/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 59/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 60/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0644 - val_mae: 0.0644
# Epoch 61/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 62/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 63/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 64/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 65/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 66/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 67/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 68/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 69/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 70/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 71/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 72/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 73/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 74/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 75/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 76/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 77/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 78/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 79/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 80/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 81/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 82/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 83/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 84/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0647 - val_mae: 0.0647
# Epoch 85/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 86/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 87/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 88/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 89/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 90/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 91/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 92/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 93/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 94/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 95/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 96/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 97/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 98/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0645 - val_mae: 0.0645
# Epoch 99/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646
# Epoch 100/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0646 - val_mae: 0.0646

# %%
def model_loss(history):
    plt.figure(figsize=(15,8))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

# invert predictions
train_predict = scaler.inverse_transform(train_predict)
trainY = scaler.inverse_transform([trainY])
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform([testY])
print("Train MAE:",mae(trainY.reshape(-1,),train_predict.reshape(-1,)))
print("Test MAE:",mae(testY.reshape(-1,),test_predict.reshape(-1,)))
model_loss(model_history)
# Out:
# Train MAE: 33.143571453821295
# Test MAE: 33.05388065005362

# %%
def prediction_plot(testY, test_predict,look_back):
    len_prediction=[x for x in range(269,300)]
    plt.plot(trainY.reshape(-1,))
    plt.plot(len_prediction, testY.reshape(-1,), marker='.', label='actual')
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
import seaborn as sns

# %%
test_predict = model.predict(testX)
test_predict = scaler.inverse_transform(test_predict)
prediction_plot(testY, test_predict,look_back)
