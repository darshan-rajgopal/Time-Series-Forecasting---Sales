# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15,8]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Thesis datasets/Monthly_Pharmaceutical_Sales.csv')
df.head()
# Out:
#         datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03    R06
# 0  2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.2
# 1  2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.2
# 2  2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.4
# 3  2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.7
# 4  2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.7

# %%
df.tail()
# Out:
#          datum   M01AB    M01AE   N02BA   N02BE   N05B  N05C    R03     R06
# 65  2019-06-30  151.54  101.627  103.20  610.00  193.0  25.0  142.0  156.04
# 66  2019-07-31  181.00  103.541   92.80  649.80  250.6  20.0  115.0  105.20
# 67  2019-08-31  181.91   88.269   84.20  518.10  237.0  26.0  145.0   97.30
# 68  2019-09-30  161.07  111.437   93.50  984.48  227.8  16.0  161.0  109.10
# 69  2019-10-31   44.37   37.300   20.65  295.15   86.0   7.0   37.0   11.13

# %%
df.shape
# Out:
# (70, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   datum   70 non-null     object
#  1   M01AB   70 non-null     float64
#  2   M01AE   70 non-null     float64
#  3   N02BA   70 non-null     float64
#  4   N02BE   70 non-null     float64
#  5   N05B    70 non-null     float64
#  6   N05C    70 non-null     float64
#  7   R03     70 non-null     float64
#  8   R06     70 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 5.0+ KB

# %%
time = pd.date_range(start='1/31/2014',periods=70,freq='M')
df['time_stamp'] = pd.DataFrame(time)
df.drop('datum',axis=1,inplace=True)
df = df.set_index('time_stamp')

# %%
df.head()
# Out:
#              M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03    R06
# time_stamp
# 2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.2
# 2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.2
# 2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.4
# 2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.7
# 2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.7

# %%
df.tail()
# Out:
#              M01AB    M01AE   N02BA   N02BE   N05B  N05C    R03     R06
# time_stamp
# 2019-06-30  151.54  101.627  103.20  610.00  193.0  25.0  142.0  156.04
# 2019-07-31  181.00  103.541   92.80  649.80  250.6  20.0  115.0  105.20
# 2019-08-31  181.91   88.269   84.20  518.10  237.0  26.0  145.0   97.30
# 2019-09-30  161.07  111.437   93.50  984.48  227.8  16.0  161.0  109.10
# 2019-10-31   44.37   37.300   20.65  295.15   86.0   7.0   37.0   11.13

# %%
df = df[['N02BE']]
df
# Out:
#                N02BE
# time_stamp
# 2014-01-31   878.030
# 2014-02-28  1001.900
# 2014-03-31   779.275
# 2014-04-30   698.500
# 2014-05-31   628.780
# ...              ...
# 2019-06-30   610.000
# 2019-07-31   649.800
# 2019-08-31   518.100
# 2019-09-30   984.480
# 2019-10-31   295.150
#
# [70 rows x 1 columns]

# %%
df = df + 1

# %%
df
# Out:
#                N02BE
# time_stamp
# 2014-01-31   879.030
# 2014-02-28  1002.900
# 2014-03-31   780.275
# 2014-04-30   699.500
# 2014-05-31   629.780
# ...              ...
# 2019-06-30   611.000
# 2019-07-31   650.800
# 2019-08-31   519.100
# 2019-09-30   985.480
# 2019-10-31   296.150
#
# [70 rows x 1 columns]

# %%
plt.plot(df)
plt.title('Monthly Pharmaceutical Sales',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
from sklearn.preprocessing import MinMaxScaler
#create numpy.ndarray 
df['N02BE'] = df['N02BE'].astype(np.float32)
df_arr = df.values
df_arr = np.reshape(df_arr, (-1, 1))
scaler = MinMaxScaler(feature_range=(0.1, 1))
df_arr = scaler.fit_transform(df_arr)

# %%
#Split data set into testing dataset and train dataset
train_size = 56
train, test =df_arr[0:train_size,:], df_arr[train_size:len(df_arr),:]
# setup look_back window 
look_back = 2
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
# reshape input to be [samples, window size, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (54, 1, 2)
# (54,)
# (12, 1, 2)
# (12,)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 133 kB 8.4 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,SimpleRNN,Dropout,Bidirectional
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(SimpleRNN(hp.Int('rnn_layer_1',min_value=32,max_value=256,step=32), activation="relu",return_sequences=True, input_shape=(1,look_back),recurrent_dropout = hp.Choice("recurrent_dropout",[0.2,0.4,0.6],default=0.4)))
    for i in range(hp.Int('n_layers', 1, 10)):
        model.add(SimpleRNN(hp.Int(f'rnn_{i}_units',min_value=32,max_value=256,step=32),activation="relu", return_sequences=True,recurrent_dropout = hp.Choice("recurrent_dropout",[0.2,0.4,0.6],default=0.4)))
    model.add(SimpleRNN(hp.Int('final_rnn_layer',min_value=32,max_value=256,step=32),activation="relu",recurrent_dropout = hp.Choice("recurrent_dropout",[0.2,0.4,0.6],default=0.4) ))
    model.add(Dense(hp.Int('dense_layer_1',min_value=32,max_value=256,step=32),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-3, max_value=1e-1, sampling="log")),
        loss='mae',
        metrics=['mae'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mae',
    max_trials=20,
    executions_per_trial=1,
    directory='project',
    project_name='pharma Sales')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 8
# rnn_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# recurrent_dropout (Choice)
# {'default': 0.4, 'conditions': [], 'values': [0.2, 0.4, 0.6], 'ordered': True}
# n_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 10, 'step': 1, 'sampling': None}
# rnn_0_units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# final_rnn_layer (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': None}
# Dropout_rate (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=500,
             batch_size=35,
             validation_data=(testX, testY))
# Out:
# Trial 20 Complete [00h 00m 41s]
# val_mae: 0.09804630279541016
#
# Best val_mae So Far: 0.09572657197713852
# Total elapsed time: 00h 11m 29s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/pharma Sales
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f29a6ae0090>
# Trial summary
# Hyperparameters:
# rnn_layer_1: 160
# recurrent_dropout: 0.4
# n_layers: 3
# rnn_0_units: 160
# final_rnn_layer: 160
# dense_layer_1: 96
# Dropout_rate: 0.2
# learning_rate: 0.021779168728807242
# rnn_1_units: 32
# rnn_2_units: 64
# rnn_3_units: 96
# rnn_4_units: 224
# rnn_5_units: 32
# Score: 0.09572657197713852
# Trial summary
# Hyperparameters:
# rnn_layer_1: 224
# recurrent_dropout: 0.4
# n_layers: 3
# rnn_0_units: 160
# final_rnn_layer: 160
# dense_layer_1: 192
# Dropout_rate: 0.1
# learning_rate: 0.020576175937476363
# rnn_1_units: 224
# rnn_2_units: 96
# rnn_3_units: 96
# rnn_4_units: 96
# rnn_5_units: 128
# rnn_6_units: 64
# rnn_7_units: 192
# Score: 0.09707774966955185
# Trial summary
# Hyperparameters:
# rnn_layer_1: 224
# recurrent_dropout: 0.6
# n_layers: 6
# rnn_0_units: 128
# final_rnn_layer: 96
# dense_layer_1: 32
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.008657947905507467
# rnn_1_units: 192
# rnn_2_units: 256
# rnn_3_units: 192
# rnn_4_units: 192
# rnn_5_units: 128
# rnn_6_units: 256
# rnn_7_units: 160
# Score: 0.0975489392876625
# Trial summary
# Hyperparameters:
# rnn_layer_1: 192
# recurrent_dropout: 0.2
# n_layers: 8
# rnn_0_units: 64
# final_rnn_layer: 256
# dense_layer_1: 64
# Dropout_rate: 0.4
# learning_rate: 0.00164990621482157
# rnn_1_units: 128
# rnn_2_units: 96
# rnn_3_units: 128
# rnn_4_units: 224
# rnn_5_units: 32
# rnn_6_units: 32
# rnn_7_units: 224
# Score: 0.09762942045927048
# Trial summary
# Hyperparameters:
# rnn_layer_1: 192
# recurrent_dropout: 0.2
# n_layers: 5
# rnn_0_units: 192
# final_rnn_layer: 192
# dense_layer_1: 160
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.006552199268517462
# rnn_1_units: 192
# rnn_2_units: 128
# rnn_3_units: 96
# rnn_4_units: 96
# rnn_5_units: 96
# rnn_6_units: 160
# rnn_7_units: 128
# Score: 0.0979849323630333
# Trial summary
# Hyperparameters:
# rnn_layer_1: 128
# recurrent_dropout: 0.6
# n_layers: 9
# rnn_0_units: 128
# final_rnn_layer: 128
# dense_layer_1: 64
# Dropout_rate: 0.0
# learning_rate: 0.010638404155204522
# rnn_1_units: 224
# rnn_2_units: 160
# rnn_3_units: 64
# rnn_4_units: 192
# rnn_5_units: 32
# rnn_6_units: 192
# rnn_7_units: 96
# rnn_8_units: 32
# Score: 0.09804630279541016
# Trial summary
# Hyperparameters:
# rnn_layer_1: 64
# recurrent_dropout: 0.2
# n_layers: 4
# rnn_0_units: 128
# final_rnn_layer: 128
# dense_layer_1: 128
# Dropout_rate: 0.4
# learning_rate: 0.003093908579078467
# rnn_1_units: 64
# rnn_2_units: 64
# rnn_3_units: 64
# rnn_4_units: 224
# rnn_5_units: 64
# rnn_6_units: 160
# rnn_7_units: 96
# Score: 0.09833139181137085
# Trial summary
# Hyperparameters:
# rnn_layer_1: 192
# recurrent_dropout: 0.2
# n_layers: 4
# rnn_0_units: 96
# final_rnn_layer: 192
# dense_layer_1: 224
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.004746679111846026
# rnn_1_units: 64
# rnn_2_units: 224
# rnn_3_units: 160
# rnn_4_units: 224
# rnn_5_units: 224
# Score: 0.09847056865692139
# Trial summary
# Hyperparameters:
# rnn_layer_1: 192
# recurrent_dropout: 0.2
# n_layers: 7
# rnn_0_units: 96
# final_rnn_layer: 64
# dense_layer_1: 96
# Dropout_rate: 0.4
# learning_rate: 0.009913923752885561
# rnn_1_units: 96
# rnn_2_units: 128
# rnn_3_units: 160
# rnn_4_units: 96
# rnn_5_units: 96
# rnn_6_units: 96
# rnn_7_units: 224
# Score: 0.09880334138870239
# Trial summary
# Hyperparameters:
# rnn_layer_1: 256
# recurrent_dropout: 0.2
# n_layers: 5
# rnn_0_units: 160
# final_rnn_layer: 96
# dense_layer_1: 64
# Dropout_rate: 0.0
# learning_rate: 0.00103699753028074
# rnn_1_units: 32
# rnn_2_units: 32
# rnn_3_units: 32
# rnn_4_units: 32
# Score: 0.09910952299833298

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(1, 12))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 160)            26080
#
#  simple_rnn_1 (SimpleRNN)    (None, 1, 160)            51360
#
#  simple_rnn_2 (SimpleRNN)    (None, 1, 32)             6176
#
#  simple_rnn_3 (SimpleRNN)    (None, 1, 64)             6208
#
#  simple_rnn_4 (SimpleRNN)    (None, 160)               36000
#
#  dense (Dense)               (None, 96)                15456
#
#  dropout (Dropout)           (None, 96)                0
#
#  dense_1 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 141,377
# Trainable params: 141,377
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

# %%
model = Sequential()
model.add(Bidirectional(SimpleRNN(32,activation='relu',input_shape=(1,look_back))))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate=0.00011779168728807242)
model.compile(optimizer = ad, loss = 'mae', metrics = ['mae'])
model_history=model.fit(trainX, trainY,validation_data=(testX, testY), batch_size = 35, epochs = 100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 287ms/step - loss: 0.3795 - mae: 0.3795 - val_loss: 0.3509 - val_mae: 0.3509
# Epoch 2/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3763 - mae: 0.3763 - val_loss: 0.3476 - val_mae: 0.3476
# Epoch 3/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3731 - mae: 0.3731 - val_loss: 0.3442 - val_mae: 0.3442
# Epoch 4/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3699 - mae: 0.3699 - val_loss: 0.3409 - val_mae: 0.3409
# Epoch 5/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3668 - mae: 0.3668 - val_loss: 0.3375 - val_mae: 0.3375
# Epoch 6/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3636 - mae: 0.3636 - val_loss: 0.3342 - val_mae: 0.3342
# Epoch 7/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3604 - mae: 0.3604 - val_loss: 0.3308 - val_mae: 0.3308
# Epoch 8/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3573 - mae: 0.3573 - val_loss: 0.3275 - val_mae: 0.3275
# Epoch 9/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3542 - mae: 0.3542 - val_loss: 0.3241 - val_mae: 0.3241
# Epoch 10/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3509 - mae: 0.3509 - val_loss: 0.3208 - val_mae: 0.3208
# Epoch 11/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3478 - mae: 0.3478 - val_loss: 0.3175 - val_mae: 0.3175
# Epoch 12/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3448 - mae: 0.3448 - val_loss: 0.3141 - val_mae: 0.3141
# Epoch 13/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3416 - mae: 0.3416 - val_loss: 0.3108 - val_mae: 0.3108
# Epoch 14/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3386 - mae: 0.3386 - val_loss: 0.3075 - val_mae: 0.3075
# Epoch 15/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3355 - mae: 0.3355 - val_loss: 0.3043 - val_mae: 0.3043
# Epoch 16/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3323 - mae: 0.3323 - val_loss: 0.3010 - val_mae: 0.3010
# Epoch 17/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3293 - mae: 0.3293 - val_loss: 0.2977 - val_mae: 0.2977
# Epoch 18/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3262 - mae: 0.3262 - val_loss: 0.2945 - val_mae: 0.2945
# Epoch 19/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3231 - mae: 0.3231 - val_loss: 0.2912 - val_mae: 0.2912
# Epoch 20/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3201 - mae: 0.3201 - val_loss: 0.2879 - val_mae: 0.2879
# Epoch 21/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3170 - mae: 0.3170 - val_loss: 0.2847 - val_mae: 0.2847
# Epoch 22/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3140 - mae: 0.3140 - val_loss: 0.2815 - val_mae: 0.2815
# Epoch 23/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3110 - mae: 0.3110 - val_loss: 0.2782 - val_mae: 0.2782
# Epoch 24/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3079 - mae: 0.3079 - val_loss: 0.2750 - val_mae: 0.2750
# Epoch 25/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3049 - mae: 0.3049 - val_loss: 0.2718 - val_mae: 0.2718
# Epoch 26/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3019 - mae: 0.3019 - val_loss: 0.2686 - val_mae: 0.2686
# Epoch 27/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2989 - mae: 0.2989 - val_loss: 0.2653 - val_mae: 0.2653
# Epoch 28/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2959 - mae: 0.2959 - val_loss: 0.2621 - val_mae: 0.2621
# Epoch 29/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2929 - mae: 0.2929 - val_loss: 0.2589 - val_mae: 0.2589
# Epoch 30/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2899 - mae: 0.2899 - val_loss: 0.2557 - val_mae: 0.2557
# Epoch 31/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2869 - mae: 0.2869 - val_loss: 0.2525 - val_mae: 0.2525
# Epoch 32/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2839 - mae: 0.2839 - val_loss: 0.2493 - val_mae: 0.2493
# Epoch 33/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2809 - mae: 0.2809 - val_loss: 0.2461 - val_mae: 0.2461
# Epoch 34/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2779 - mae: 0.2779 - val_loss: 0.2429 - val_mae: 0.2429
# Epoch 35/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2750 - mae: 0.2750 - val_loss: 0.2397 - val_mae: 0.2397
# Epoch 36/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2720 - mae: 0.2720 - val_loss: 0.2365 - val_mae: 0.2365
# Epoch 37/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2689 - mae: 0.2689 - val_loss: 0.2334 - val_mae: 0.2334
# Epoch 38/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2659 - mae: 0.2659 - val_loss: 0.2302 - val_mae: 0.2302
# Epoch 39/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2629 - mae: 0.2629 - val_loss: 0.2270 - val_mae: 0.2270
# Epoch 40/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2600 - mae: 0.2600 - val_loss: 0.2238 - val_mae: 0.2238
# Epoch 41/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2569 - mae: 0.2569 - val_loss: 0.2206 - val_mae: 0.2206
# Epoch 42/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2540 - mae: 0.2540 - val_loss: 0.2174 - val_mae: 0.2174
# Epoch 43/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2510 - mae: 0.2510 - val_loss: 0.2143 - val_mae: 0.2143
# Epoch 44/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2479 - mae: 0.2479 - val_loss: 0.2111 - val_mae: 0.2111
# Epoch 45/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2450 - mae: 0.2450 - val_loss: 0.2079 - val_mae: 0.2079
# Epoch 46/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2420 - mae: 0.2420 - val_loss: 0.2047 - val_mae: 0.2047
# Epoch 47/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2392 - mae: 0.2392 - val_loss: 0.2017 - val_mae: 0.2017
# Epoch 48/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2364 - mae: 0.2364 - val_loss: 0.1991 - val_mae: 0.1991
# Epoch 49/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2335 - mae: 0.2335 - val_loss: 0.1964 - val_mae: 0.1964
# Epoch 50/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2306 - mae: 0.2306 - val_loss: 0.1938 - val_mae: 0.1938
# Epoch 51/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2278 - mae: 0.2278 - val_loss: 0.1911 - val_mae: 0.1911
# Epoch 52/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2249 - mae: 0.2249 - val_loss: 0.1884 - val_mae: 0.1884
# Epoch 53/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2222 - mae: 0.2222 - val_loss: 0.1858 - val_mae: 0.1858
# Epoch 54/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2192 - mae: 0.2192 - val_loss: 0.1831 - val_mae: 0.1831
# Epoch 55/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2164 - mae: 0.2164 - val_loss: 0.1805 - val_mae: 0.1805
# Epoch 56/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2136 - mae: 0.2136 - val_loss: 0.1778 - val_mae: 0.1778
# Epoch 57/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2107 - mae: 0.2107 - val_loss: 0.1751 - val_mae: 0.1751
# Epoch 58/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2079 - mae: 0.2079 - val_loss: 0.1724 - val_mae: 0.1724
# Epoch 59/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2050 - mae: 0.2050 - val_loss: 0.1697 - val_mae: 0.1697
# Epoch 60/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2021 - mae: 0.2021 - val_loss: 0.1670 - val_mae: 0.1670
# Epoch 61/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1992 - mae: 0.1992 - val_loss: 0.1643 - val_mae: 0.1643
# Epoch 62/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1964 - mae: 0.1964 - val_loss: 0.1616 - val_mae: 0.1616
# Epoch 63/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1935 - mae: 0.1935 - val_loss: 0.1589 - val_mae: 0.1589
# Epoch 64/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1906 - mae: 0.1906 - val_loss: 0.1562 - val_mae: 0.1562
# Epoch 65/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1877 - mae: 0.1877 - val_loss: 0.1535 - val_mae: 0.1535
# Epoch 66/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1848 - mae: 0.1848 - val_loss: 0.1508 - val_mae: 0.1508
# Epoch 67/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1820 - mae: 0.1820 - val_loss: 0.1481 - val_mae: 0.1481
# Epoch 68/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1790 - mae: 0.1790 - val_loss: 0.1453 - val_mae: 0.1453
# Epoch 69/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1763 - mae: 0.1763 - val_loss: 0.1426 - val_mae: 0.1426
# Epoch 70/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1732 - mae: 0.1732 - val_loss: 0.1398 - val_mae: 0.1398
# Epoch 71/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1704 - mae: 0.1704 - val_loss: 0.1371 - val_mae: 0.1371
# Epoch 72/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1676 - mae: 0.1676 - val_loss: 0.1344 - val_mae: 0.1344
# Epoch 73/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1648 - mae: 0.1648 - val_loss: 0.1317 - val_mae: 0.1317
# Epoch 74/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1620 - mae: 0.1620 - val_loss: 0.1292 - val_mae: 0.1292
# Epoch 75/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1593 - mae: 0.1593 - val_loss: 0.1270 - val_mae: 0.1270
# Epoch 76/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1566 - mae: 0.1566 - val_loss: 0.1249 - val_mae: 0.1249
# Epoch 77/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1540 - mae: 0.1540 - val_loss: 0.1227 - val_mae: 0.1227
# Epoch 78/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1512 - mae: 0.1512 - val_loss: 0.1206 - val_mae: 0.1206
# Epoch 79/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1486 - mae: 0.1486 - val_loss: 0.1184 - val_mae: 0.1184
# Epoch 80/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1460 - mae: 0.1460 - val_loss: 0.1163 - val_mae: 0.1163
# Epoch 81/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1436 - mae: 0.1436 - val_loss: 0.1142 - val_mae: 0.1142
# Epoch 82/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1411 - mae: 0.1411 - val_loss: 0.1128 - val_mae: 0.1128
# Epoch 83/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1386 - mae: 0.1386 - val_loss: 0.1114 - val_mae: 0.1114
# Epoch 84/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1363 - mae: 0.1363 - val_loss: 0.1099 - val_mae: 0.1099
# Epoch 85/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1337 - mae: 0.1337 - val_loss: 0.1085 - val_mae: 0.1085
# Epoch 86/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1317 - mae: 0.1317 - val_loss: 0.1071 - val_mae: 0.1071
# Epoch 87/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1294 - mae: 0.1294 - val_loss: 0.1057 - val_mae: 0.1057
# Epoch 88/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1275 - mae: 0.1275 - val_loss: 0.1045 - val_mae: 0.1045
# Epoch 89/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1257 - mae: 0.1257 - val_loss: 0.1036 - val_mae: 0.1036
# Epoch 90/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1241 - mae: 0.1241 - val_loss: 0.1027 - val_mae: 0.1027
# Epoch 91/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1228 - mae: 0.1228 - val_loss: 0.1018 - val_mae: 0.1018
# Epoch 92/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1214 - mae: 0.1214 - val_loss: 0.1010 - val_mae: 0.1010
# Epoch 93/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1202 - mae: 0.1202 - val_loss: 0.1006 - val_mae: 0.1006
# Epoch 94/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1190 - mae: 0.1190 - val_loss: 0.1004 - val_mae: 0.1004
# Epoch 95/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1178 - mae: 0.1178 - val_loss: 0.1001 - val_mae: 0.1001
# Epoch 96/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1171 - mae: 0.1171 - val_loss: 0.0999 - val_mae: 0.0999
# Epoch 97/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1161 - mae: 0.1161 - val_loss: 0.0996 - val_mae: 0.0996
# Epoch 98/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1153 - mae: 0.1153 - val_loss: 0.0994 - val_mae: 0.0994
# Epoch 99/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1145 - mae: 0.1145 - val_loss: 0.0992 - val_mae: 0.0992
# Epoch 100/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1137 - mae: 0.1137 - val_loss: 0.0990 - val_mae: 0.0990

# %%
def model_loss(history):
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
trainX_2 = scaler.inverse_transform(trainX.reshape(-1,3))
trainY_2 = scaler.inverse_transform([trainY])
testX_2 = scaler.inverse_transform(testX.reshape(-1,3))
testY_2 = scaler.inverse_transform([testY])

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

# invert predictions
train_predict = scaler.inverse_transform(train_predict)
trainY = scaler.inverse_transform([trainY])
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform([testY])
print("Train MAE:",mae(trainY.reshape(-1,),train_predict.reshape(-1,)))
print("Test MAE:",mae(testY.reshape(-1,),test_predict.reshape(-1,)))
model_loss(model_history)
# Out:
# Train MAE: 233.4187151539347
# Test MAE: 204.2828952728427

# %%
import seaborn as sns

# %%
def prediction_plot(testY, test_predict,look_back):
    len_prediction=[x for x in range(54,66)]
    plt.plot(trainY.reshape(-1,))
    plt.plot(len_prediction, testY.reshape(-1,), marker='.', label='actual')
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
test_predict = model.predict(testX)
test_predict = scaler.inverse_transform(test_predict)
prediction_plot(testY, test_predict,look_back)
